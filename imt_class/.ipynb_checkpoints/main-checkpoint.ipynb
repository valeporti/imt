# %%
# %matplotlib notebook
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import MeanShift, estimate_bandwidth
from mpl_toolkits.mplot3d import Axes3D
from itertools import cycle

# %%
def draw_correlation_matrix(df):
    sns.set(style="white")
    # Compute the correlation matrix
    corr = df.corr()
    # Generate a mask for the upper triangle
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)
    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, square=True, 
                linewidths=.5, cbar_kws={"shrink": .5})
    
def take_out_sign(df, array_columns_name):
    for column_name in array_columns_name:
        df[column_name] = [float(re.sub('\$', '', i)) for i in df[column_name]]
        
def clustering_2d(x, y, df, q=0.2):
    X = np.asarray([[[a for a in df[x]][i], [b for b in df[y]][i]] for i in range(len(df))])
    bandwidth = estimate_bandwidth(X, quantile=q, n_samples=len(df))
    ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    ms.fit(X)
    labels = ms.labels_
    cluster_centers = ms.cluster_centers_
    labels_unique = np.unique(labels)
    n_clusters_ = len(labels_unique)
    
    print("number of estimated clusters : %d" % n_clusters_)
    #-------------------------------------------------------
    plt.figure()
    plt.clf()
    colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
    for k, col in zip(range(n_clusters_), colors):
        my_members = labels == k
        cluster_center = cluster_centers[k]
        plt.plot(X[my_members, 0], X[my_members, 1], col + '.')
        plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
                 markeredgecolor='k', markersize=14)
    plt.title('Estimated number of clusters: %d' % n_clusters_)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.show()
    return labels

def clustering_3d(x, y, z, df, q=0.2):
    X = np.asarray([[df[x][i], df[y][i], df[z][i]] for i in range(len(df))])
    bandwidth = estimate_bandwidth(X, quantile=q, n_samples=len(df))
    ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    ms.fit(X)
    labels = ms.labels_
    cluster_centers = ms.cluster_centers_
    labels_unique = np.unique(labels)
    n_clusters_ = len(labels_unique)
    
    print("number of estimated clusters : %d" % n_clusters_)
    #-------------------------------------------------------
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X[:,0], X[:,1], X[:,2], marker='.')
    ax.scatter(cluster_centers[:,0], cluster_centers[:,1], cluster_centers[:,2], marker='x', color='red', s=300, linewidth=5, zorder=10)
    plt.show()
    return labels

def boxplot(x, df, labels):
    X = df[x]
    labels_unique = np.unique(labels)
    n_clusters = len(labels_unique)
    data = []
    for i in range(n_clusters):
        data.append(X[labels==i])
    fig, ax = plt.subplots()
    ax.set_title('Multiple Samples with Different sizes')
    ax.boxplot(data)
    plt.show()
    
def hide_current_axis(*args, **kwds):
    plt.gca().set_visible(False)

# %%
df = pd.read_csv('./data/dow_jones_index.data')

df.head()
# Out:
#    quarter stock       date    open    high     low   close     volume  \
# 0        1    AA   1/7/2011  $15.82  $16.72  $15.78  $16.42  239655616
# 1        1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2        1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3        1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4        1    AA   2/4/2011  $16.18  $17.39  $16.18  $17.14  154387761
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0               3.79267                                 NaN
# 1              -4.42849                            1.380223
# 2              -2.47066                          -43.024959
# 3               1.63831                            9.355500
# 4               5.93325                            1.987452
#
#    previous_weeks_volume next_weeks_open next_weeks_close  \
# 0                    NaN          $16.71           $15.97
# ...

# %%
take_out_sign(df, ['open','high','low','close','next_weeks_open','next_weeks_close'])

df.head()
# Out:
#    quarter stock       date   open   high    low  close     volume  \
# 0        1    AA   1/7/2011  15.82  16.72  15.78  16.42  239655616
# 1        1    AA  1/14/2011  16.71  16.71  15.64  15.97  242963398
# 2        1    AA  1/21/2011  16.19  16.38  15.60  15.79  138428495
# 3        1    AA  1/28/2011  15.87  16.63  15.82  16.13  151379173
# 4        1    AA   2/4/2011  16.18  17.39  16.18  17.14  154387761
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0               3.79267                                 NaN
# 1              -4.42849                            1.380223
# 2              -2.47066                          -43.024959
# 3               1.63831                            9.355500
# 4               5.93325                            1.987452
#
#    previous_weeks_volume  next_weeks_open  next_weeks_close  \
# 0                    NaN            16.71             15.97
# 1            239655616.0            16.19             15.79
# ...

# %%
draw_correlation_matrix(df)
# Out:
# <img src="data:image/png;base64,..." width="1100">

# %%
g = sns.pairplot(df)
g.map_upper(hide_current_axis)
# Out:
# <img src="data:image/png;base64,..." width="3500">

# %%
labels = clustering_2d('open', 'high', df, 0.2)
# Out:
# number of estimated clusters : 4
# <img src="data:image/png;base64,..." width="640">

# %%
boxplot('percent_change_next_weeks_price', df, labels)

# %%
labels = clustering_3d('open', 'high', 'low', df, 0.2)
# Out:
# number of estimated clusters : 4
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #

# %%
columns = ['open',
           'percent_change_price',
           'percent_change_volume_over_last_wk',
           'days_to_next_dividend',
           'percent_return_next_dividend'
          ]

# %%
g = sns.pairplot(df[columns])
g.map_upper(hide_current_axis)
# Out:
# <img src="data:image/png;base64,..." width="1250">
# /home/valeporti/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/valeporti/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df =df.dropna(how='any')

for col_i in columns:
    for col_j in columns[1:]:
        labels = clustering_2d(col_i, col_j, df, 0.2)
        boxplot('percent_change_next_weeks_price', df, labels)
# Out:
# number of estimated clusters : 4
# number of estimated clusters : 5
# number of estimated clusters : 5
# number of estimated clusters : 4
# number of estimated clusters : 6
# number of estimated clusters : 6
# number of estimated clusters : 9
# number of estimated clusters : 6
# number of estimated clusters : 6
# number of estimated clusters : 5
# number of estimated clusters : 8
# number of estimated clusters : 6
# number of estimated clusters : 9
# number of estimated clusters : 8
# number of estimated clusters : 10
# number of estimated clusters : 9
# number of estimated clusters : 6
# number of estimated clusters : 6
# number of estimated clusters : 9
# number of estimated clusters : 3
