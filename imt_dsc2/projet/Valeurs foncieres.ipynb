# %% [markdown]
# ### Équipe:
# > PORTILLO Valentín, RODRIGUEZ Ricardo Moisés, WANG XUE, YUAN Zheng

# %% [markdown]
# ## Description of the dataset "valeurs foncières" (2018 set)

# %%
import pandas as pd
import seaborn as sns
import pprint as pp

# %%
file = './data/full.csv'

# %%
df = pd.read_csv(file, sep=',')
# Out:
# /home/valeporti/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (8,10,12,14,16,17,18,20,22,26,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# **Titles**

# %%
titles = df.columns
pp.pprint(titles)
# Out:
# Index(['id_mutation', 'date_mutation', 'numero_disposition', 'nature_mutation',
#        'valeur_fonciere', 'adresse_numero', 'adresse_suffixe',
#        'adresse_nom_voie', 'adresse_code_voie', 'code_postal', 'code_commune',
#        'nom_commune', 'code_departement', 'ancien_code_commune',
#        'ancien_nom_commune', 'id_parcelle', 'ancien_id_parcelle',
#        'numero_volume', 'lot1_numero', 'lot1_surface_carrez', 'lot2_numero',
#        'lot2_surface_carrez', 'lot3_numero', 'lot3_surface_carrez',
#        'lot4_numero', 'lot4_surface_carrez', 'lot5_numero',
#        'lot5_surface_carrez', 'nombre_lots', 'code_type_local', 'type_local',
#        'surface_reelle_bati', 'nombre_pieces_principales',
#        'code_nature_culture', 'nature_culture', 'code_nature_culture_speciale',
#        'nature_culture_speciale', 'surface_terrain', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# **DataFrame shot**

# %%
df
# Out:
#           id_mutation date_mutation  numero_disposition nature_mutation  \
# 0              2018-1    2018-01-03                   1           Vente
# 1              2018-1    2018-01-03                   1           Vente
# 2              2018-2    2018-01-04                   1           Vente
# 3              2018-2    2018-01-04                   1           Vente
# 4              2018-2    2018-01-04                   1           Vente
# ...               ...           ...                 ...             ...
# 2338997  2018-1020921    2018-12-04                   2           Vente
# 2338998  2018-1020922    2018-12-31                   1           Vente
# 2338999  2018-1020923    2018-12-31                   1           Vente
# 2339000  2018-1020924    2018-12-27                   1           Vente
# 2339001  2018-1020925    2018-12-28                   1           Vente
#
#          valeur_fonciere  adresse_numero adresse_suffixe    adresse_nom_voie  \
# ...

# %%
categorical_titles = ['numero_disposition', 'nature_mutation', 'numero_volume', 'nombre_lots', 
                     'nombre_pieces_principales', ]
id_title = ['id_mutation', 'id_parcelle', 'ancien_id_parcelle']
date_title = ['date_mutation']
string_titles = ['adresse_numero', 'adresse_suffixe', 'adresse_nom_voie', 'adresse_code_voie', 'code_postal', 
                 'code_commune', 'nom_commune', 'code_departement', 'ancien_code_commune', 'ancien_nom_commune', 
                 'lot1_numero', 'lot2_numero', 'lot3_numero', 'lot4_numero', 'lot5_numero', 'code_type_local', 
                 'type_local', 'code_nature_culture', 'nature_culture', 'code_nature_culture_speciale', 
                 'nature_culture_speciale']
numeric_titles = ['valeur_fonciere', 'lot1_surface_carrez', 'lot2_surface_carrez', 'lot3_surface_carrez', 
                 'lot4_surface_carrez', 'lot5_surface_carrez', 'surface_reelle_bati', 'surface_terrain', 
                 'longitude', 'latitude']

# %%
# numeric
df[numeric_titles] = df[numeric_titles].apply(pd.to_numeric)
# categorical
df[categorical_titles] = df[categorical_titles].astype('category')
"""for i, title in enumerate(categorical_titles):
    print(df[title].unique())"""
# ids
df[id_title] = df[id_title].astype('object')
# dates
df[date_title] = df[date_title].apply(pd.to_datetime)
# string
df[string_titles] = df[string_titles].astype('object')

# %% [markdown]
# **Description of numercial columns**

# %%
df.describe()
# Out:
#        valeur_fonciere  lot1_surface_carrez  lot2_surface_carrez  \
# count     2.317731e+06        204176.000000         48750.000000
# mean      6.676013e+05            63.071021            63.742052
# std       5.361343e+06           137.056940            58.547203
# min       1.500000e-01             0.100000             0.100000
# 25%       5.500000e+04            33.780000            42.790000
# 50%       1.400000e+05            53.370000            60.680000
# 75%       2.500000e+05            73.220000            76.140000
# max       6.295914e+08          9999.000000          8284.000000
#
#        lot3_surface_carrez  lot4_surface_carrez  lot5_surface_carrez  \
# count          4740.000000          1265.000000           527.000000
# mean             90.115890           131.179668           130.462030
# std             279.939753           420.688811           474.140969
# min               0.400000             0.400000             0.930000
# ...

# %% [markdown]
# **Description of categorial columns**

# %%
df.describe(include=['category'])
# Out:
#         numero_disposition nature_mutation  numero_volume  nombre_lots  \
# count              2339002         2339002         6096.0      2339002
# unique                 362               6          688.0           73
# top                      1           Vente            1.0            0
# freq               2204577         2113403         1173.0      1628795
#
#         nombre_pieces_principales
# count                   1211836.0
# unique                       41.0
# top                           0.0
# freq                     365010.0

# %% [markdown]
# **Description of ids and strings in the dataset**

# %%
df.describe(include=['object'])
# Out:
#         id_mutation  adresse_numero adresse_suffixe adresse_nom_voie  \
# count       2339002       1356897.0          100338          2307388
# unique      1020925          6498.0              41           377793
# top     2018-925260             1.0               B       LE VILLAGE
# freq           3844         58147.0           60550            23309
#
#        adresse_code_voie  code_postal  code_commune nom_commune  \
# count            2308268    2308188.0       2339002     2339002
# unique             16382       5758.0         31076       28988
# top                 B004      31200.0         31555    Toulouse
# freq               10693       6877.0         24829       24829
#
#         code_departement  ancien_code_commune  ... lot2_numero lot3_numero  \
# count            2339002              40524.0  ...    145272.0     23375.0
# unique                99                574.0  ...      5157.0      1113.0
# ...

# %% [markdown]
# **Description of date columns**

# %%
df.describe(include=['datetime'])
# Out:
#               date_mutation
# count               2339002
# unique                  361
# top     2018-06-29 00:00:00
# freq                  23813
# first   2018-01-01 00:00:00
# last    2018-12-31 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2339002 entries, 0 to 2339001
# Data columns (total 40 columns):
# id_mutation                     object
# date_mutation                   datetime64[ns]
# numero_disposition              category
# nature_mutation                 category
# valeur_fonciere                 float64
# adresse_numero                  object
# adresse_suffixe                 object
# adresse_nom_voie                object
# adresse_code_voie               object
# code_postal                     object
# code_commune                    object
# nom_commune                     object
# code_departement                object
# ancien_code_commune             object
# ancien_nom_commune              object
# id_parcelle                     object
# ancien_id_parcelle              object
# numero_volume                   category
# lot1_numero                     object
# lot1_surface_carrez             float64
# lot2_numero                     object
# ...

# %%
df.isnull().sum()
# Out:
# id_mutation                           0
# date_mutation                         0
# numero_disposition                    0
# nature_mutation                       0
# valeur_fonciere                   21271
# adresse_numero                   982105
# adresse_suffixe                 2238664
# adresse_nom_voie                  31614
# adresse_code_voie                 30734
# code_postal                       30814
# code_commune                          0
# nom_commune                           0
# code_departement                      0
# ancien_code_commune             2298478
# ancien_nom_commune              2298478
# id_parcelle                           0
# ancien_id_parcelle              2338703
# numero_volume                   2332906
# lot1_numero                     1628795
# lot1_surface_carrez             2134826
# lot2_numero                     2193730
# lot2_surface_carrez             2290252
# lot3_numero                     2315627
# ...
